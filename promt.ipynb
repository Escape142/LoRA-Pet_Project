# %%
import pandas as pd
import random

# Define maximum token limit for the prompt
MAX_TOKENS = 2048

def generate_prompt_from_excel(excel_file, max_examples=30):
    prompt = "Task: Translate customer requests to positions in the catalog.\n"
    prompt += "Dataset:\n\n"
    examples = []

    df = pd.read_excel(excel_file)
    for _, row in df.iterrows():
        input_text = row['Наименование заказчика']
        output_text = [
            f"Ед. Изм.\t- {row['Ед. Изм.']}",
            f"Простая/составная\t- {row['Простая/составная']}",
            f"Продукт/рукав\t- {row['Продукт/рукав']}",
            f"Длина\t- {row['Длина']}",
            f"Фитинг левый\t- {row['Фитинг левый']}",
            f"Фитинг правый\t- {row['Фитинг правый']}",
        ]
        examples.append((input_text, output_text))

    # Shuffle examples and select a subset
    random.shuffle(examples)
    examples = examples[:max_examples]

    for input_text, output_text in examples:
        prompt += f"Input: {input_text}\n"
        prompt += "Output:\n"
        prompt += '\n'.join(output_text) + '\n\n'

    # Add context
    prompt += "Context: The inputs contain a mix of Russian and English words along with technical specifications like DN sizes, fittings, and standards such as ГОСТ. Ensure the output provides the corresponding product, its unit of measurement, whether it's simple or compound, length, and left and right fittings."

    return prompt

# Example usage:
excel_file = '/app/Fayl_dlya_raboty.xlsx'  # Replace with your Excel file path
prompt = generate_prompt_from_excel(excel_file)
print(prompt)
# Out:
# Task: Translate customer requests to positions in the catalog.
# Dataset:
#
# Input: Рукав 15,9-110-1000-0,2-11/11-М27х1,5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN16
# Длина	- 1000
# Фитинг левый	- DKOL27X1,5DN16
# Фитинг правый	- DKOL27X1,5DN16
#
# Input: РВД HDB520-PA420SF9V4A-90-920X/GEVS
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SH DN19
# Длина	- 920
# Фитинг левый	- SFS41,3DN19
# Фитинг правый	- SFS41,3(90)DN19
#
# Input: РВД D12 P350 2SN DKOS M24*1,5 L2600 DIN853
# Output:
# Ед. Изм.	- Шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN-K DN12
# Длина	- 2600
# Фитинг левый	- DKOS24x1,5DN12
# Фитинг правый	- DKOS24x1,5DN12
#
# Input: Фитинг JIC-(Г)-9/16"-18-45-8
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- JIC9/16"(45)DN8
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД 2SC-16-280-1500 DKOS(Г) M30х2
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN16
# Длина	- 1500
# Фитинг левый	- DKOS30x2DN16
# Фитинг правый	- DKOS30x2DN16
#
# Input: РВД 2SN-12-275-2500 DK M30х2
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN12
# Длина	- 2500
# Фитинг левый	- DK30x2DN12
# Фитинг правый	- DK30x2DN12
#
# Input: РВД 2SN-10-330-500 DK M16х1,5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN8
# Длина	- 500
# Фитинг левый	- DK16x1,5DN8
# Фитинг правый	- DK16x1,5DN8
#
# Input: РВД 2SN-10-330-580 DK M16х1,5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN8
# Длина	- 580
# Фитинг левый	- DK16x1,5DN8
# Фитинг правый	- DK16x1,5DN8
#
# Input: РВД 4SP-19-380-600 DKOS(Г) M36х2
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SH DN19
# Длина	- 600
# Фитинг левый	- DKOS36x2DN19
# Фитинг правый	- DKOS36x2DN19
#
# Input: РВД10-140-3200-26/26-М18х1,5/М18х1,5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN10
# Длина	- 3200
# Фитинг левый	- DK18x1,5DN10
# Фитинг правый	- DK18x1,5DN10
#
# Input: РВД HDB525-PA525AOSAPA525AOSA-3000X/GEVS
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SH DN25
# Длина	- 3000
# Фитинг левый	- DKOS42x2DN25
# Фитинг правый	- DKOS42x2DN25
#
# Input: РВД 4SP-19-350
# Output:
# Ед. Изм.	- М
# Простая/составная	- Простая
# Продукт/рукав	- 4SP DN19
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД HDB410-PA410AOS08V4A-1150X/GEVS
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SP DN10
# Длина	- 1150
# Фитинг левый	- DKOS20x1,5DN10
# Фитинг правый	- DKOS20x1,5DN10
#
# Input: РВД 2SN-8-350-600 1A8DS5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN8
# Длина	- 600
# Фитинг левый	- DKOS20x1,5DN8
# Фитинг правый	- DKOS20x1,5DN8
#
# Input: Рукав РВД 12,7-166-1450 М22х1,5-У1
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN12
# Длина	- 1450
# Фитинг левый	- DK22x1,5DN12
# Фитинг правый	- DK22x1,5DN12
#
# Input: Фитинг ORFS-(Г)-1"-14-18-90-16
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- ORFS1"(90)DN16
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: Фитинг DN16 SFL 38,1(0)
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- SFL38,1DN16
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД 25 4SН БРС L=10000 EN856
# Output:
# Ед. Изм.	- Шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SH DN25
# Длина	- 10000
# Фитинг левый	- Stecko DN25
# Фитинг правый	- Stecko DN25
#
# Input: Фитинг JIC-(Г) 9/16"-18-45-DN6
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- JIC9/16"(45)DN6
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД D25 P380 4SP JIC 1,5/16 0° L12500 DIN856
# Output:
# Ед. Изм.	- Шт.
# Простая/составная	- Составная
# Продукт/рукав	- 4SH DN25
# Длина	- 12500
# Фитинг левый	- JIC1.5/16"DN25
# Фитинг правый	- JIC1.5/16"DN25
#
# Input: РВД 2SN-16-250-1200 DK(Г) M27х1.5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN16
# Длина	- 1200
# Фитинг левый	- DK27x1,5DN16
# Фитинг правый	- DK27x1,5DN16
#
# Input: Фитинг DN38 SFL 71,4(45)
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- SFL71,4(45)DN38
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: Фитинг ORFS-(Г)-1"-14-18-0-16
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- ORFS1"DN16
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД D12 P320 2SN БРС L2200 DIN853
# Output:
# Ед. Изм.	- Шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN-K DN12
# Длина	- 2200
# Фитинг левый	- Stecko DN12
# Фитинг правый	- Stecko DN12
#
# Input: РВД7,9-140-3000-0,115-27/27М14Х1,5/М14У1
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN8
# Длина	- 3000
# Фитинг левый	- DK14x1,5DN8
# Фитинг правый	- DK14x1,5DN8
#
# Input: Фитинг DN32 SFL 50,8(45)
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- SFL50,8(45)DN31
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: Рукав РВД 16.120.1350.0,2.11/11М27х1,5/М
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN16
# Длина	- 1350
# Фитинг левый	- DK27x1,5DN16
# Фитинг правый	- DK27x1,5DN16
#
# Input: Фитинг DN20 SFL 44,5(90)
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Простая
# Продукт/рукав	- SFL44,5(90)DN19
# Длина	- нет
# Фитинг левый	- нет
# Фитинг правый	- нет
#
# Input: РВД 2SN-10-330-1300-DKOS/DKOS М22х1,5
# Output:
# Ед. Изм.	- шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN10
# Длина	- 1200
# Фитинг левый	- DKOS22x1,5DN10
# Фитинг правый	- DKOS22x1,5DN10
#
# Input: РВД D31 P215 2SN БРС L20000 DIN 853
# Output:
# Ед. Изм.	- Шт.
# Простая/составная	- Составная
# Продукт/рукав	- 2SN DN31
# Длина	- 20000
# Фитинг левый	- Stecko DN31
# Фитинг правый	- Stecko DN31
#
# Context: The inputs contain a mix of Russian and English words along with technical specifications like DN sizes, fittings, and standards such as ГОСТ. Ensure the output provides the corresponding product, its unit of measurement, whether it's simple or compound, length, and left and right fittings.
